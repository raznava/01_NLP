# %%
from BLT_pdf_tools import feature_pdf_extractor, feature_pdf_extractor_table, feature_pdf_extractor_graph, feature_pdf_total_article_count
# Out:
# [nltk_data] Downloading package punkt to /Users/raznava/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Path to PDF data
directory = './PDF_1_1000'
# Path to output data
path_output = './OUTPUT/'
# defining the name of csv and xlsx files
name_file_output_csv = '02_feature_1_1000_v02.csv'
name_file_output_xlsx = '02_feature_1_1000_v02.xlsx'
feature_sort= 'SAR'
number_articles= 56
size_x=10
size_y=10

# %%
feature_pdf_extractor_table(directory,path_output, name_file_output_csv,name_file_output_xlsx)

# %%
number =  True # True or False
color = 'rocket_r' # 'viridis', 'plasma', 'inferno', 'magma', 'cividis',"rocket_r","mako","YlGnBu","coolwarm"

# %%
feature_pdf_extractor_graph(path_output, name_file_output_csv,name_file_output_xlsx, feature_sort, number_articles, size_x, size_y,number, color)

# %%
path_output = './OUTPUT/'
name_file_output_csv = '02_feature_1_1000_V01.csv'
y_label = ''
x_label = ''
title = ''
size_x = 3
size_y = 3
color_bar = 'skyblue' #

# %%
feature_pdf_total_article_count(path_output, name_file_output_csv,y_label, x_label, title, color_bar, size_x, size_y)
